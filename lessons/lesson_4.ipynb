# %% [markdown]
# **Библиотека(package)** это набор готовых инструментов, функций и классов,
# которые можно подключить к Python.

# %%
import math
print(math.sqrt(25))
x = 25**(1/2)
print(x)

# %% [markdown]
# Загрузка библиотек:

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Пример датасета, функция **load_dataset**

# %%
df = sns.load_dataset("tips")

# %%
df

# %%
df.head(10)

# %%
df.columns # df.index

# %%
df.describe()

# %%
df.info()

# %%
df.dtypes

# %%
df.columns

# %%
df.shape # df.size

# %%
df["tip"].max()

# %%
df["tip"].mean()

# %%
df["day"].unique() # df["day"].nunique()

# %%
df[df['size']==4].shape[0]

# %%
df[(df["total_bill"] > 30) & (df["sex"] == "Female")]

# %%
df[(df["total_bill"] > 30) & (df["sex"] == "Female")]['tip']

# %%
df.loc[(df["total_bill"] > 30) & (df["sex"] == "Female"), ["tip", "day"]]

# %%
df.loc[0:1]

# %%
df.loc[0:2, ['tip', 'day']]

# %%
df.groupby("day")["total_bill"].mean()

# %%
df.sort_values(['tip', 'size'], ascending= True)

# %%
q1 = df["total_bill"].quantile(0.75)
q1

# %%
df.describe()

# %% [markdown]
# # Задача

# %% [markdown]
# 1) Загрузить датасет с помощью функции https://seaborn.pydata.org/generated/seaborn.load_dataset.html
# 2) Изучить структуру таблицы
#     - Какие типы данных в таблице?
#     - Какие колонки числовые?
#     - Какие категориальные?
#     - Что показывают min/max/Q1/Q3?
#     - **Найти IQR ->** Какая колонка имеет выбросы?
# 3) Проанализировать признаки с помощью функций median/mode/mean
# 4) Отфильтровать данные с помощью loc, с несколькими признаками
#     - **Пример** из датасета tips - *Курящие мужчины, с чеком выше 40, посетившие ресторан во время ужина*
# 5) Сортировать признаки по определенным критериям (просто использую sort_values)
#
# **Задание в основном на креативность и анализ**
